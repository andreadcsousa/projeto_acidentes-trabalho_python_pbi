# %%
import pandas as pd

catweb_2024 = pd.read_csv('bases_tratadas/catweb_v1.csv', encoding='latin1', sep=';', dtype=object)

# %%
catweb_2024.head()
# Out:
#   dt_acidente cd6_mun cd_classe  cd_cbo cd_cid        causa_acidente  \
# 0  02/01/2024  000000      1555  623310    S81  Motocicleta, Motonet
# 1  01/01/2024  230440      8411  223505    Z20         Não informado
# 2  02/01/2024  230428      4321  313105    S92  Queda de Pes. em Mes
# 3  01/01/2024  420540      8411  515105    S52  Rua e Estrada - Supe
# 4  02/01/2024  355030      4321  514320    S23  Escada Permanente Cu
#
#   tipo_beneficio tipo_segurado    nm_sexo dt_nascimento tipo_acidente  \
# 0             Pa     Empregado  Masculino    13/02/1995       Trajeto
# 1             Pa     Empregado   Feminino    19/10/1967        Típico
# 2             Pa     Empregado  Masculino    29/07/1981        Típico
# 3             Pa     Empregado   Feminino    06/05/1986       Trajeto
# 4             Pa     Empregado   Feminino    30/03/1966        Típico
#
#              tipo_lesao           local_lesao indica_obito
# 0  Escoriacao, Abrasao   Perna (Do Tornozelo,          Não
# ...

# %% [markdown]
# Tratamento: Espécie do benefício

# %%
beneficio = {
    'Pa': 'Auxílio-acidente',
    'Auxílio Doenca por A': 'Auxílio-doença acidentário',
    'Pensão por Morte Aci': 'Pensão por morte acidental'
}

catweb_2024['tipo_beneficio'] = catweb_2024['tipo_beneficio'].replace(beneficio)

# %% [markdown]
# Tratamento: Agente Causador Acidente

# %%
causa = {
    'Absorcao de Substanc' : 'Absorção (por contato) de substância cáustica, tóxica ou nociva',
    'Acido' : 'Ácido',
    'Aerodispersoides' : 'Aerodispersoides',
    'Aeronave' : 'Aeronave',
    'Agente do Acidente I' : 'Agente do acidente inexistente',
    'Agente do Acidente,' : 'Agente do acidente não identificado',
    'Agente Infeccioso ou' : 'Agente infeccioso ou parasitário',
    'Agua - Usar Quando O' : 'Água (usar quando o estado líquido contribuir preponderantemente para a ocorrência)',
    'Alavanca, Pe-De-Cabr' : 'Alavanca, pé-de-cabra',
    'Alcali' : 'Álcali',
    'Alcool' : 'Álcool',
    'Alicate, Torques, Te' : 'Alicate, torques, tenaz',
    'Andaime, Plataforma' : 'Andaime, plataforma',
    'Animal Vivo' : 'Animal vivo',
    'Aprision. Em, Sob ou' : 'Aprisionamento em, sob ou entre objetos',
    'Aprision. Em, Sobre' : 'Aprisionamento em, sobre ou entre objetos',
    'Arco Eletrico' : 'Arco elétrico',
    'Arco Eletrico - Equi' : 'Arco elétrico',
    'Area ou Ambiente de' : 'Área ou ambiente de trabalho',
    'Arquibancada, Estadi' : 'Arquibancada, estádio',
    'Arquivo, Fichario, E' : 'Arquivo, fichário, estante',
    'Asfalto, Alcatrao, P' : 'Asfalto, alcatrão, piche',
    'Ataque de Ser Vivo c' : 'Ataque de ser vivo',
    'Ataque de Ser Vivo p' : 'Ataque de ser vivo',
    'Ataque de Ser Vivo,' : 'Ataque de ser vivo não identificado',
    'Atrito ou Abrasao po' : 'Atrito ou abrasão',
    'Atrito ou Abrasao, N' : 'Atrito ou abrasão não identificado',
    'Balcao, Bancada - Mo' : 'Balcão, bancada',
    'Barril, Barrica, Bar' : 'Barril, barrica, barrilete, tambor',
    'Bicicleta' : 'Bicicleta',
    'Bomba' : 'Bomba',
    'Britador, Moinho - M' : 'Britador, moinho',
    'Cadeira Banco - Mobi' : 'Cadeira banco',
    'Cais, Doca - Edifici' : 'Cais, doca',
    'Caixa, Engradado, Ca' : 'Caixa, engradado, caixote',
    'Caixao Pneumatico -' : 'Caixão pneumático',
    'Calcada ou Caminho p' : 'Calçada ou caminho para pedestre',
    'Caldeira' : 'Caldeira',
    'Caldeira, Vaso Sob P' : 'Caldeira, vaso sob pressão não identificado',
    'Canal, Fosso' : 'Canal, fosso',
    'Carne e Derivados -' : 'Carne e derivados',
    'Carro de Mao' : 'Carro de mão',
    'Carvao' : 'Carvão',
    'Ceramica' : 'Cerâmica',
    'Ceramica, Nic' : 'Cerâmica não identificada',
    'Cereal e Derivados' : 'Cereal e derivados',
    'Chao - Superficie Ut' : 'Chão',
    'Chave de Parafuso- F' : 'Chave de parafuso',
    'Chave de Porca ou de' : 'Chave de porca ou de abertura regulável, chave de boca',
    'Composto Aromatico (' : 'Composto aromático',
    'Composto de Arsenio' : 'Composto de arsênio',
    'Composto de Fosforo' : 'Composto de fósforo',
    'Composto Metalico (D' : 'Composto metálico',
    'Composto Organico Ha' : 'Composto orgânico halogenado',
    'Condutor - Equip. El' : 'Condutor',
    'Coque' : 'Coque',
    'Corda, Cabo, Corrent' : 'Corda, cabo, corrente',
    'Correia - Dispositiv' : 'Correia',
    'Corrente, Corda, Cab' : 'Corrente, corda, cabo',
    'Cortadeira, Guilhoti' : 'Cortadeira, guilhotina',
    'Couro Cru ou Curtido' : 'Couro cru ou curtido',
    'Deposito Fixo (Tanqu' : 'Depósito fixo (tanque, silo, paiol, etc.)',
    'Dique, Barragem - Ed' : 'Dique, barragem',
    'Dispositivo de Trans' : 'Dispositivo de transmissão de energia mecânica não identificado',
    'Edificio - Edificio' : 'Edifício',
    'Edificio ou Estrutur' : 'Edifício ou estrutura',
    'Eletrica, Exposicao' : 'Elétrica, exposição',
    'Elevador - Equip. de' : 'Elevador',
    'Elevador de Cacamba' : 'Elevador de caçamba para mineração',
    'Embalagem e Recipien' : 'Embalagem, recipiente (vazio ou cheio) não identificado',
    'Embreagem de Friccao' : 'Embreagem de fricção',
    'Empilhadeira' : 'Empilhadeira',
    'Energia' : 'Energia',
    'Engrenagem - Disposi' : 'Engrenagem',
    'Enxada, Enxadao, Sac' : 'Enxada, enxadão, sacho',
    'Equip. de Aqueciment' : 'Equipamento de aquecimento elétrico',
    'Equip. de Guindar, N' : 'Equipamento de guindar não identificado',
    'Equip. de Iluminacao' : 'Equipamento de iluminação',
    'Equip. de Raios X -' : 'Equipamento de raios X',
    'Equip. Eletrico, Nic' : 'Equipamento elétrico não identificado',
    'Equip. Eletrolitico' : 'Equipamento eletrolítico',
    'Equip. Emissor de Ra' : 'Equipamento emissor de radiação não ionizante',
    'Equip. Magnetico - E' : 'Equipamento magnético',
    'Equip. ou Substancia' : 'Equipamento ou substância emissor de radiação ionizante',
    'Equip. para Trabalho' : 'Equipamento para trabalho em ambiente de pressão anormal',
    'Escada Movel ou Fixa' : 'Escada móvel ou fixada',
    'Escada Permanente Cu' : 'Escada permanente cujos degraus permitem apoio integral do pé, degrau',
    'Escafandro - Equip.' : 'Escafandro',
    'Escavacao (Para Edif' : 'Escavação (para edifício, estrada, etc.)',
    'Escavacao, Fosso, Tu' : 'Escavação, fosso, túnel não identificado',
    'Esforco Excessivo ao' : 'Esforço excessivo ao manejar objeto',
    'Esforco Excessivo, N' : 'Esforço excessivo não identificado',
    'Esmeril- Ferramenta' : 'Esmeril',
    'Exposicao a Pressao' : 'Exposição à pressão',
    'Faca, Facao- Ferrame' : 'Faca, facão',
    'Ferramenta Acionada' : 'Ferramenta acionada por explosivo',
    'Ferramenta de Soldag' : 'Ferramenta de soldagem',
    'Ferramenta Manual se' : 'Ferramenta manual sem força motriz',
    'Ferramenta Portatil' : 'Ferramenta portátil com força motriz ou aquecimento',
    'Ferramenta, Maquina,' : 'Ferramenta, máquina, equipamento, veículo',
    'Ferro de Passar- Fer' : 'Ferro de passar',
    'Fogo-Chama,Material' : 'Fogo, chama, material incandescente ou quente, fumaça',
    'Formao, Cinzel- Ferr' : 'Formão, cinzel',
    'Forno, Estufa, Retor' : 'Forno, estufa, retorta, aquecedor de ambiente, fogão',
    'Frasco, Garrafa - Em' : 'Frasco, garrafa',
    'Fruta e Derivados' : 'Fruta e derivados',
    'Furadeira, Broqueade' : 'Furadeira, broqueadeira, torno, fresa',
    'Garfo, Ancinho, Forc' : 'Garfo, ancinho, forcado',
    'Gas Carbonico (Dioxi' : 'Gás carbônico',
    'Gas e Vapor' : 'Gás e vapor',
    'Gas Encanado de Carv' : 'Gás encanado de carvão',
    'Gasoleo, Oleo Diesel' : 'Gasóleo, óleo diesel',
    'Gasolina (Exceto Qua' : 'Gasolina',
    'Gerador - Equip. Ele' : 'Gerador',
    'Guincho Eletrico - E' : 'Guincho elétrico',
    'Guincho Pneumatico -' : 'Guincho pneumático',
    'Guindaste - Equip. d' : 'Guindaste',
    'Hidrocarboneto Gasos' : 'Hidrocarboneto gasoso',
    'Imersao' : 'Imersão',
    'Impacto de Pes. Cont' : 'Impacto de pessoa contra objeto',
    'Impacto Sofrido por' : 'Impacto sofrido por pessoa',
    'Inalacao de Substanc' : 'Inalação de substância cáustica, tóxica ou nociva',
    'Inalacao, Ingestao o' : 'Inalação, ingestão e absorção não identificado',
    'Ingestao de Substanc' : 'Ingestão de substancia cáustica, tóxica ou nociva',
    'Jato de Areia- Ferra' : 'Jato de areia',
    'Laminadora, Calandra' : 'Laminadora, calandra',
    'Legume, Verdura e De' : 'Legume, verdura e derivados',
    'Leite e Derivados -' : 'Leite e derivados',
    'Lima, Grosa- Ferrame' : 'Lima, grosa',
    'Liquido, Nic' : 'Líquido não identificado',
    'Louca de Mesa e Outr' : 'Louça de mesa e outros utensílios',
    'Louca Sanitaria (Pia' : 'Louca sanitária',
    'Luminaria, Globo, Ia' : 'Luminária, globo, lâmpada',
    'Macaco (Mecanico, Hi' : 'Macaco (mecânico, hidráulico, pneumático)',
    'Machadinha, Enxo- Fe' : 'Machadinha, enxó',
    'Machado- Ferramenta' : 'Machado',
    'Madeira (Toro, Madei' : 'Madeira',
    'Maquina Agricola' : 'Máquina agrícola',
    'Maquina de Aparafusa' : 'Máquina de aparafusar',
    'Maquina de Costurar' : 'Máquina de costurar e de pespontar',
    'Maquina de Embalar o' : 'Máquina de embalar ou empacotar',
    'Maquina de Escritori' : 'Máquina de escritório',
    'Maquina de Fundir, d' : 'Máquina de fundir, de forjar, de soldar',
    'Maquina de Imprimir' : 'Máquina de imprimir',
    'Maquina de Mineracao' : 'Máquina de mineração e perfuração (de túnel, poço, etc.)',
    'Maquina de Terraplen' : 'Máquina de terraplenagem e construção de estrada',
    'Maquina Textil' : 'Máquina têxtil',
    'Maquina, Nic' : 'Máquina não identificada',
    'Martelete, Socador-' : 'Martelete, socador',
    'Martelo, Malho, Marr' : 'Martelo, malho, marreta',
    'Masarico - Ferrament' : 'Maçarico',
    'Medicamento em Geral' : 'Medicamento em geral (exceto produto biológico)',
    'Mesa Elastica Desmon' : 'Mesa elástica desmontável',
    'Mesa, Carteira, Exce' : 'Mesa, carteira, exceto mesa elástica desmontável',
    'Metal - Inclui Liga' : 'Metal (exceto minério)',
    'Misturador, Batedeir' : 'Misturador, batedeira, agitador',
    'Mobiliario e Acessor' : 'Mobiliário e acessórios',
    'Monoxido de Carbono' : 'Monóxido de carbono',
    'Motocicleta, Motonet' : 'Motocicleta, motoneta',
    'Motor (Combustao Int' : 'Motor (combustão interna, vapor)',
    'Motor Eletrico - Equ' : 'Motor elétrico',
    'Motor, Bomba, Turbin' : 'Motor, bomba, turbina',
    'Nafta e Solvente de' : 'Nafta e solvente de nafta',
    'Não informado' : 'Não informado',
    'Neblina' : 'Neblina',
    'Oleo Combustivel' : 'Óleo combustível',
    'Osso - Produto Anima' : 'Osso',
    'Oxidos de Nitrogenio' : 'Óxidos de nitrogênio (vapores nitrosos)',
    'Pa Mecanica, Draga -' : 'Pá mecânica, draga',
    'Pa, Cavadeira- Ferra' : 'Pá, cavadeira',
    'Painel de Controle,' : 'Painel de controle, barramento, chave, interruptor, disjuntor, fusível',
    'Papel e Pasta para P' : 'Papel e pasta para papel',
    'Parafina, Oleo Lubri' : 'Parafina, óleo lubrificante e de corte, graxas',
    'Particulas - nao Ide' : 'Partículas não identificadas',
    'Passarela ou Platafo' : 'Passarela ou plataforma permanentes',
    'Pau de Carga - Equip' : 'Pau de carga',
    'Pele, Crina, Pelo, L' : 'Pele, crina, pelo, lã',
    'Pena - Produto Anima' : 'Pena',
    'Peneira Mecanica, Ma' : 'Peneira mecânica, máquina separadora',
    'Perfuratriz- Ferrame' : 'Perfuratriz',
    'Petroleo Bruto, Brut' : 'Petróleo bruto, bruto reduzido',
    'Picareta- Ferramenta' : 'Picareta',
    'Piso de Andaime e Pl' : 'Piso de andaime e plataforma desmontável',
    'Piso de Edificio - S' : 'Piso de edifício',
    'Piso de Mina - Super' : 'Piso de mina',
    'Piso de Veiculo - Su' : 'Piso de veiculo',
    'Plaina- Ferramenta M' : 'Plaina',
    'Plaina, Tupia - Maqu' : 'Plaina, tupia',
    'Plastico - Inclui Po' : 'Plástico (não inclui produto a ser usado na fabricação de plástico)',
    'Poco, Entrada, Galer' : 'Poço, entrada, galeria, etc. de mina',
    'Politriz, Enceradeir' : 'Politriz, enceradeira',
    'Politriz, Lixadora,' : 'Politriz, lixadora, esmeril',
    'Poluicao da Agua, Ac' : 'Poluição da água',
    'Poluicao do Ar, Acao' : 'Poluição do ar',
    'Ponte Rolante - Equi' : 'Ponte rolante',
    'Ponte, Viaduto - Edi' : 'Ponte, viaduto',
    'Prensa - Maquina' : 'Prensa',
    'Pressao Ambiente Alt' : 'Pressão ambiente alta (trabalho em caixão pneumático, mergulho)',
    'Pressao Ambiente Bai' : 'Pressão ambiente baixa (ar rarefeito)',
    'Pressao Ambiente, Ex' : 'Pressão ambiente, exposição a variações de pressão atmosférica',
    'Produto Alimenticio' : 'Produto alimentício (inclui carne, leite e derivados, legumes, frutas, cereais e derivados)',
    'Produto Animal, Nic' : 'Produto animal não identificado',
    'Produto Biologico (S' : 'Produto biológico (soro, toxina, antitoxina, vacina, plasma)',
    'Produto de Limpeza,' : 'Produto de limpeza, sabão, detergente',
    'Produto de Petroleo' : 'Produto de petróleo e de carvão não identificado',
    'Produto Mineral Meta' : 'Produto mineral metálico',
    'Produto Mineral nao' : 'Produto mineral não metálico',
    'Produtos Alimenticio' : 'Produto alimentício (inclusive de origem animal) não identificado',
    'Pua, Trado, Verruma,' : 'Pua, trado, verruma, máquina de furar manual',
    'Puncao, Ponteiro, Va' : 'Punção, ponteiro, vazador, talhadeira',
    'Queda de Pes. com Di' : 'Queda de pessoa com diferença de nível',
    'Queda de Pes. em Mes' : 'Queda de pessoa em mesmo nível',
    'Querosene' : 'Querosene',
    'Radiacao Ionizante,' : 'Radiação ionizante',
    'Radiacao nao Ionizan' : 'Radiação não ionizante',
    'Rampa - Superficie U' : 'Rampa',
    'Reacao do Corpo a Mo' : 'Reação do corpo a seus movimentos',
    'Reator (Inclui Combu' : 'Reator (inclui combustível e resíduo)',
    'Rebitadeira- Ferrame' : 'Rebitadeira',
    'Rebocador Mecanico,' : 'Rebocador mecânico, mula mecânica',
    'Reostato, Dispositiv' : 'Reostato, capacitor, retificador, bateria de acumuladores',
    'Revestimento Ceramic' : 'Revestimento cerâmico (azulejo, mosaico, etc.)',
    'Rua e Estrada - Supe' : 'Rua e estrada',
    'Ruido' : 'Ruído',
    'Ruido, Exposicao A' : 'Ruído, exposição a ruído excessivo ou contínuo',
    'Ser Vivo, Nic' : 'Ser vivo não identificado',
    'Serra - Maquina' : 'Serra',
    'Serra- Ferramenta Po' : 'Serra portátil',
    'Serra, Serrote- Ferr' : 'Serra, serrote',
    'Substancia Quimica,' : 'Substância química, material, produto não identificado',
    'Sucata, Entulho, Res' : 'Sucata, entulho, resíduo',
    'Superficie de Susten' : 'Superfície de sustentação não identificado',
    'Superficie e Estrutu' : 'Superfície e estrutura não identificado',
    'Talha - Equip. de Gu' : 'Talha',
    'Talhadeira- Ferramen' : 'Talhadeira',
    'Tambor, Polia, Rolda' : 'Tambor, polia, roldana',
    'Tanque, Cilindro (Tr' : 'Tanque, cilindro (transportáveis e não sob pressão)',
    'Tapete, Forracao de' : 'Tapete, forração de piso, capacho',
    'Telhado' : 'Telhado',
    'Temperatura Ambiente' : 'Temperatura ambiente (não inclui a de objeto ou substância quente)',
    'Temperatura Muito Al' : 'Temperatura muito alta',
    'Temperatura Muito Ba' : 'Temperatura muito baixa',
    'Tesoura, Guilhotina,' : 'Tesoura, guilhotina, máquina de cortar',
    'Tesoura, Tesourao- F' : 'Tesoura, tesourão',
    'Texteis - Inclui Fib' : 'Têxteis',
    'Tijolo e Telha - Cer' : 'Tijolo e telha',
    'Torre, Poste - Edifi' : 'Torre, poste',
    'Transformador, Conve' : 'Transformador, conversor',
    'Transportador com Fo' : 'Transportador com força motriz',
    'Transportador por Gr' : 'Transportador por gravidade',
    'Transportador, Nic' : 'Transportador não identificado',
    'Trator' : 'Trator',
    'Triciclo' : 'Triciclo',
    'Tubo Sob Pressao (Ma' : 'Tubo sob pressão (mangueira ou tubo para liquido, gás ou vapor)',
    'Tubo, Manilha - Cera' : 'Tubo, manilha',
    'Tunel' : 'Túnel',
    'Turbina' : 'Turbina',
    'Vaso Sob Pressao (Pa' : 'Vaso sob pressão (para líquido, gás ou vapor)',
    'Vegetal - Planta, Ar' : 'Vegetal - planta, árvore, em estado natural',
    'Veiculo Aquatico' : 'Veículo aquático',
    'Veiculo de Terraplen' : 'Veículo de terraplenagem',
    'Veiculo de Tracao An' : 'Veículo de tração animal',
    'Veiculo Deslisante' : 'Veículo deslizante',
    'Veiculo Funicular (T' : 'Veículo funicular (tração por cabo)',
    'Veiculo Rodoviario M' : 'Veículo rodoviário motorizado',
    'Veiculo Sobre Trilho' : 'Veículo sobre trilho',
    'Veiculo, Nic' : 'Veículo não identificado',
    'Vestuario, Nic' : 'Vestuário não identificado',
    'Vibracao, Exposicao' : 'Vibração, exposição a vibração de corpo inteiro ou localizada',
    'Vidraria, Fibra de V' : 'Vidraria, fibra de vidro, lâmina, etc., exceto frasco, garrafa'
}

catweb_2024['causa_acidente'] = catweb_2024['causa_acidente'].replace(causa)

# %% [markdown]
# Tratamento: Natureza da Lesão

# %%
lesao = {
    'Amputacao ou Enuclea' : 'Amputação ou enucleação',
    'Asfixia, Estrangulam' : 'Asfixia, estrangulamento, afogamento',
    'Choque Eletrico e El' : 'Choque elétrico e eletrocussão',
    'Concussao Cerebral  ' : 'Concussão cerebral',
    'Congelamento, Geladu' : 'Congelamento, geladura',
    'Contusao, Esmagament' : 'Contusão, esmagamento',
    'Corte, Laceracao, Fe' : 'Corte, laceração, ferida contusa, ferida aberta',
    'Dermatose (Erupcao, ' : 'Dermatose (erupção, inflamação da pele, furúnculo)',
    'Distensao, Torcao   ' : 'Distensão, torção',
    'Doenca Contagiosa ou' : 'Doença contagiosa ou infecciosa',
    'Doenca, Nic         ' : 'Doença não identificada',
    'Efeito de Radiacao (' : 'Efeito de radiação',
    'Envenenamento Sistem' : 'Envenenamento sistêmico',
    'Escoriacao, Abrasao ' : 'Escoriação, abrasão',
    'Fratura             ' : 'Fratura',
    'Hernia de Qualquer N' : 'Hérnia de qualquer natureza, ruptura',
    'Inflamacao de Articu' : 'Inflamação de articulação, tendão ou músculo',
    'Intermacao, Insolaca' : 'Intermação, insolação, cãibra, exaustão',
    'Lesao Imediata      ' : 'Lesão imediata',
    'Lesao Imediata, Nic ' : 'Lesão imediata não identificada',
    'Lesoes Multiplas    ' : 'Lesões múltiplas',
    'Luxacao             ' : 'Luxação',
    'Outras Lesoes, Nic  ' : 'Outras lesões não identificadas',
    'Perda ou Diminuicao ' : 'Perda ou diminuição de sentido',
    'Pneumoconiose (Silic' : 'Pneumoconiose (silicose, asbestose, etc.)',
    'Queimadura ou Escald' : 'Queimadura ou escaldadura',
    'Queimadura Quimica (' : 'Queimadura química'
}

catweb_2024['tipo_lesao'] = catweb_2024['tipo_lesao'].replace(lesao)

# %% [markdown]
# Tratamento: Parte Corpo Atingida

# %%
local = {
    'Abdome (Inclusive Or' : 'Abdome (inclusive órgãos internos)',
    'Antebraco (Entre O P' : 'Antebraço (entre o punho e o cotovelo)',
    'Aparelho Circulatori' : 'Aparelho circulatório',
    'Aparelho Digestivo  ' : 'Aparelho digestivo',
    'Aparelho Genito-Urin' : 'Aparelho gênito-urinário',
    'Aparelho Respiratori' : 'Aparelho respiratório',
    'Artelho             ' : 'Artelho',
    'Articulacao do Torno' : 'Articulação do tornozelo',
    'Boca (Inclusive Labi' : 'Boca (inclusive lábios, dentes, língua, garganta e paladar)',
    'Braco (Acima do Coto' : 'Braço (acima do cotovelo)',
    'Braco (Entre O Punho' : 'Braço (entre o punho e o ombro)',
    'Cabeca, Nic         ' : 'Cabeça',
    'Cabeca, Partes Multi' : 'Cabeça, partes múltiplas',
    'Cotovelo            ' : 'Cotovelo',
    'Coxa                ' : 'Coxa',
    'Cranio (Inclusive En' : 'Crânio (inclusive encéfalo)',
    'Dedo                ' : 'Dedo',
    'Dorso (Inclusive Mus' : 'Dorso (inclusive músculos dorsais, coluna e medula espinhal)',
    'Face, Partes Multipl' : 'Face, partes múltiplas',
    'Joelho              ' : 'Joelho',
    'Localizacao da Lesao' : 'Localização da lesão não identificada',
    'Mandibula (Inclusive' : 'Mandíbula (inclusive queixo)',
    'Mao (Exceto Punho ou' : 'Mão (exceto punho ou dedos)',
    'Membros Inferiores, ' : 'Membros inferiores',
    'Membros Superiores, ' : 'Membros superiores',
    'Nariz (Inclusive Fos' : 'Nariz (inclusive fossas nasais, seios da face e olfato)',
    'Olho (Inclusive Nerv' : 'Olho (inclusive nervo ótico e visão)',
    'Ombro               ' : 'Ombro',
    'Ouvido (Externo, Med' : 'Ouvido (externo, médio, interno, audição e equilíbrio)',
    'Partes Multiplas - A' : 'Partes múltiplas',
    'Pe (Exceto Artelhos)' : 'Pé (exceto artelhos)',
    'Perna (Do Tornozelo,' : 'Perna (do tornozelo, exclusive, ao joelho, exclusive)',
    'Perna (Entre O Torno' : 'Perna (entre o tornozelo e a pélvis)',
    'Pescoco             ' : 'Pescoço',
    'Punho               ' : 'Punho',
    'Quadris (Inclusive P' : 'Quadris (inclusive pélvis, órgãos pélvicos e nádegas)',
    'Sistema Musculo-Esqu' : 'Sistema musculoesquelético',
    'Sistema Nervoso     ' : 'Sistema nervoso',
    'Sistemas e Aparelhos' : 'Sistemas e aparelhos',
    'Torax (Inclusive Org' : 'Tórax (inclusive órgãos internos)',
    'Tronco, Nic         ' : 'Tronco',
    'Tronco, Parte Multip' : 'Tronco, partes múltiplas'
}

catweb_2024['local_lesao'] = catweb_2024['local_lesao'].replace(local)

# %% [markdown]
# Cálculo: Idade pela data de nascimento

# %%
catweb_2024['dt_acidente'] = pd.to_datetime(catweb_2024['dt_acidente'], format='%d/%m/%Y', dayfirst=True)
catweb_2024['dt_nascimento'] = pd.to_datetime(catweb_2024['dt_nascimento'], format='%d/%m/%Y', dayfirst=True)

catweb_2024['nu_idade'] = (catweb_2024['dt_acidente'] - catweb_2024['dt_nascimento']).dt.days // 365

# %% [markdown]
# Seleciona e reordena as colunas

# %%
catweb_2024 = catweb_2024[['dt_acidente', 'cd6_mun', 'cd_classe', 'cd_cbo', 'cd_cid', 'causa_acidente', 'tipo_beneficio', 'tipo_segurado', 'nm_sexo', 'nu_idade', 'tipo_acidente', 'tipo_lesao', 'local_lesao', 'indica_obito']]

# %%
catweb_2024.head()
# Out:
#   dt_acidente cd6_mun cd_classe  cd_cbo cd_cid  \
# 0  2024-01-02  000000      1555  623310    S81
# 1  2024-01-01  230440      8411  223505    Z20
# 2  2024-01-02  230428      4321  313105    S92
# 3  2024-01-01  420540      8411  515105    S52
# 4  2024-01-02  355030      4321  514320    S23
#
#                                       causa_acidente    tipo_beneficio  \
# 0                              Motocicleta, motoneta  Auxílio-acidente
# 1                                      Não informado  Auxílio-acidente
# 2                     Queda de pessoa em mesmo nível  Auxílio-acidente
# 3                                      Rua e estrada  Auxílio-acidente
# 4  Escada permanente cujos degraus permitem apoio...  Auxílio-acidente
#
#   tipo_segurado    nm_sexo  nu_idade tipo_acidente           tipo_lesao  \
# 0     Empregado  Masculino        28       Trajeto  Escoriação, abrasão
# 1     Empregado   Feminino        56        Típico       Lesão imediata
# ...

# %%
catweb_2024.to_csv('bases_tratadas/catweb_v2.csv', index=False, encoding='latin1', sep=';')
